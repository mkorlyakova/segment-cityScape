# %% [markdown]
# <a href="https://colab.research.google.com/github/mkorlyakova/segment-cityScape/blob/master/city_Scapes_%D0%A1%D0%B5%D0%B3%D0%BC%D0%B5%D0%BD%D1%82%D0%B0%D1%86%D0%B8%D1%8F_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Импорт и инсталяция необходимого окружения
#
# Грузим модули

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Conv2DTranspose, concatenate, Activation, MaxPooling2D, Conv2D, BatchNormalization
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils
from google.colab import files
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import VGG16
import numpy as np
from PIL import Image
import tensorflow as tf


# Это своя метрика на Tensorflow DICE COEFF (https://towardsdatascience.com/metrics-to-evaluate-your-semantic-segmentation-model-6bcb99639aa2#:~:text=3.-,Dice%20Coefficient%20(F1%20Score),of%20union%20in%20section%202).)

def dice_coef(y_true, y_pred):
    return (2. * K.sum(y_true * y_pred) + 1.) / (K.sum(y_true) + K.sum(y_pred) + 1.)

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# Загружаем картинки для сегментации (имена одинаковые):
#
# - /images/изображение.png - это сам кадр
# - /labels/изображение.png - это разметка
#
# Грузим репозиторий из git c проектом

# %%
# !git clone -l -s https://github.com/mkorlyakova/Segmentation.git cloned-repo
# Out:
# Cloning into 'cloned-repo'...
# warning: --local is ignored
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 10 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (10/10), done.

# %% [markdown]
# Открываем архив (это зависит от архива)
#
# тут по zip, поэтому грузим libarchive

# %%
# https://pypi.python.org/pypi/libarchive
# !apt-get -qq install -y libarchive-dev && pip install -q -U libarchive
import libarchive
# Out:
# Selecting previously unselected package libarchive-dev:amd64.
# (Reading database ... 144676 files and directories currently installed.)
# Preparing to unpack .../libarchive-dev_3.2.2-3.1ubuntu0.6_amd64.deb ...
# Unpacking libarchive-dev:amd64 (3.2.2-3.1ubuntu0.6) ...
# Setting up libarchive-dev:amd64 (3.2.2-3.1ubuntu0.6) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
#      |████████████████████████████████| 163kB 4.7MB/s
#   Building wheel for libarchive (setup.py) ... done

# %% [markdown]
# Раскрываем архив на виртуальной машине (картинок немного 17 шт.)

# %%
import libarchive.public

with open('/content/cloned-repo/images.zip', 'rb') as f:
    for entry in libarchive.public.memory_pour(f.read()):
        print(entry)

with open('/content/cloned-repo/labels.zip', 'rb') as f:
    for entry in libarchive.public.memory_pour(f.read()):
        print(entry)

# %% [markdown]
# Проверяем, что архивы раскрылись

# %%
# !ls
# Out:
# cloned-repo  images  labels  sample_data

# %% [markdown]
# Прочитаем списки наших файлов (проверить идентичность, если имена одинаковые или собрать порядок чтения любым доступным способом)

# %%
import os, fnmatch
imag = os.listdir('/content/images/')
imag_label = os.listdir('/content/labels/')

# %%
imag,imag_label
# Out:
# (['00_000200.png',
#   '00_001000.png',
#   '00_000600.png',
#   '00_002800.png',
#   '00_002200.png',
#   '00_001600.png',
#   '00_003400.png',
#   '00_003000.png',
#   '00_001400.png',
#   '00_003200.png',
#   '00_000400.png',
#   '00_002000.png',
#   '00_001800.png',
#   '00_002400.png',
#   '00_001200.png',
#   '00_000800.png',
#   '00_002600.png'],
#  ['00_000200.png',
#   '00_001000.png',
#   '00_000600.png',
#   '00_002800.png',
#   '00_002200.png',
#   '00_001600.png',
#   '00_003400.png',
#   '00_003000.png',
#   '00_001400.png',
#   '00_003200.png',
#   '00_000400.png',
#   '00_002000.png',
#   '00_001800.png',
#   '00_002400.png',
#   '00_001200.png',
#   '00_000800.png',
#   '00_002600.png'])

# %% [markdown]
# Задаю маршрут для чтения

# %%
PAHT_label = '/content/labels/'
PAHT_image = '/content/images/'

# %% [markdown]
# #Загружаем и уменьшаем картинки
#
# можно обойтись исходным размером или взять другой
#
# ВАЖНО - размер по обеим сторонам должен делиться на 2 несколько раз (сколько будет сжатий кадра)

# %%
images = []
segments = []
image_size = (200,600)
for i_name in imag:
  images.append(image.load_img(PAHT_image+i_name ,target_size=image_size))
  segments.append(image.load_img(PAHT_label+i_name, target_size=image_size))

# %% [markdown]
# Посмотрели на входные кадры

# %%
plt.imshow(images[0].convert('RGBA'))
plt.show()

# %% [markdown]
# Посмотрим на цели

# %%
plt.imshow(segments[0].convert('RGBA'))
plt.show()

# %% [markdown]
# #Создаём обучающую выборку

# %% [markdown]
# Собираем входные примеры:

# %%
import cv2

# %% [markdown]
# Построим цвета , воспринимаемого диапазона для сегментированной картинки - это результат разметки, которую принес разметчик

# %% [markdown]
# Color Coding:
#
# Name	(r,g,b)	    7-Class mapping
#
# Car	  ( 0, 0,255)	Object
#
# Road	(255, 0, 0)	Road
#
# Mark	(255,255, 0)	Road
#
# Building	( 0,255, 0)	Building
#
# Sidewalk	(255, 0,255)	Road
#
# Tree/Bush	( 0,255,255)	Tree/Bush
#
# Pole	(255, 0,153)	Sign/Pole
#
# Sign	(153, 0,255)	Sign/Pole
#
# Person	( 0,153,255)	Object
#
# Wall	(153,255, 0)	Building
#
# Sky	(255,153, 0)	Sky
#
# Curb	( 0,255,153)	Road
#
# Grass/Dirt	( 0,153,153)	Grass/Dirt
#
# Void	( 0, 0, 0)	Void

# %% [markdown]
# Делаем конвертер в one-hot_encoding для выходных примеров

# %%
def Color2index(y):
  # y - входное rgb изображение для текущей легенды разметки
  arr_col=[[0,0,255],[255,0,0],[255,255,0],[0,255,0],[255,0,255],[0,255,255],[255,0,153],[153,0,255],[0,153,255],[153,255,0],[255,153,0],[0,255,153],[0,153,153],[0,0,0]]
  y_ind = np.zeros((y.shape[0],y.shape[1]))
  y_cat = np.zeros((y.shape[0],y.shape[1], len(arr_col)))
  i = 1
  for i_color in arr_col:
    ind_i = np.where((y[:,:,0]==i_color[0])&(y[:,:,1]==i_color[1])&(y[:,:,2]==i_color[2]))
    y_ind[ind_i[0],ind_i[1]] = i
    y_cat[ind_i[0],ind_i[1], i-1] = 1 
    i += 1
  
  return y_cat, y_ind, i-1
  
# проверяем, как это отработало  
cat_yi,ind_yi,h = Color2index(image.img_to_array(segments[0]))
plt.imshow(ind_yi.astype(float)/h)
plt.show()

# %%
plt.imshow(cat_yi[:,:,4])
plt.show()

# %%
cat_yi.shape
# Out:
# (200, 600, 14)

# %% [markdown]
# Сегментированную картинку в  One hot encoding (разметка на 14 классов)**
#
# Делаем Аугментацию:
#
# - кадрируем на картинки 200х200 исходный кадр
# - изменяю яркость в перделах 20% и строю по 10 случайных подкаров

# %%
# Строим тренировочный набор на 15 кадрах исходной выборки
xTrain= []
yTrain = []

# размер кадра аугментации по горизонтали:
w=200
for i in range(len(images)-2):
  # читаем исходный кадр и его разметку
  img  = images[i]
  seg = segments[i]
  # переводим разметку в ohe
  y_cat,_,_ = Color2index(image.img_to_array(seg))
  x = image.img_to_array(img)
  
  # аугментация кадрированием
  for s in [0,1,2]:
    xTrain.append(x[:,(w)*s:w*(s+1),:])
    yTrain.append(y_cat[:,(w)*s:w*(s+1),:]) 
  # аугментация кадрированием и случайным изменением яркости  
  for k in range(10):
    x_br = image.img_to_array(image.apply_brightness_shift( img,np.random.rand(1)/5+0.8))
    sx=np.random.randint(x.shape[1]-w)
    xTrain.append(x_br[:,sx:w+sx,:])
    yTrain.append(y_cat[:,sx:w+sx,:])

xTrain = np.array(xTrain)
yTrain = np.array(yTrain)

# Строим тестовый набор на 2 кадрах исходной выборки
xTest = []
yTest = []

# читаем изображения тестового набора (2 последних)
for i in range(2):
  img  = images[-1-i]
  seg = segments[-1-i]
  y_cat,_,_ = Color2index(image.img_to_array(seg))
  x = image.img_to_array(img)
  # аугментация кадрированием
  for s in [0,1,2]:
    xTest.append(x[:,(w)*s:w*(s+1),:])
    yTest.append(y_cat[:,(w)*s:w*(s+1),:]) 
  # аугментация кадрированием и сдвигом яркости
  for k in range(10):
    x_br = image.img_to_array(image.apply_brightness_shift( img,np.random.rand(1)/5+0.8))
    sx=np.random.randint(x.shape[1]-w)
    xTest.append(x_br[:,sx:w+sx,:])
    yTest.append(y_cat[:,sx:w+sx,:])

xTest = np.array(xTest)
yTest = np.array(yTest)

# %% [markdown]
# Размеры тренировочной части примеров

# %%
print(xTrain.shape)
# Out:
# (195, 200, 200, 3)

# %%
print(yTrain.shape)
# Out:
# (195, 200, 200, 14)

# %% [markdown]
# Посмотрим , что получили по итогам конструирования выборки для тренировки

# %%
n = 10 # номер примера

# смотрим класс 0 - машинки
seg = yTrain[n][:,:,0]
img = xTrain[n]
plt.imshow(seg.astype(float))
plt.title('один класс из сегментов')
plt.show()
plt.imshow(img.astype(int))
plt.title('оригинал из кадрирования')
plt.show()

# %% [markdown]
# Смотрим на размер примеров для тестов и обучения

# %%
print('число примеров для тренировки: ',xTrain.shape[0])
print('число примеров для теста: ',xTest.shape[0])
# Out:
# число примеров для тренировки:  195
# число примеров для теста:  26

# %% [markdown]
# #Создаём и обучаем U-net
#
# Создадим сеть на основе претренированной модели VGG16 (Imagenet - там похожие по смыслу картинки при обучении)

# %%
from tensorflow.keras.utils import plot_model

# %% [markdown]
# **Претренированная  Unet**
#
# Грузим VGG16 и определяем список слоев для работы :
#
# - смотрим на схему сжатия и не идем дальше 25х25  (нужно будет переделать на нормальные размеры типа 256х1024 - при чтении исходных кадров, тогда можно сжимать до 2х2 :))
# - отделяю выход 13-го слоя, для работы в моей сети
# - все слои замораживаю (все 18 слоев)
# - от последнего рабочего слоя VGG16 (block4_conv3 (Conv2D)) ,буду надстраивать свою сеть
# - при обучении используем размер тензоров (,200, 200, 3)(,200,200,14)
# - после обучения перестраиваю сеть на размер (,200, 600, 3)(,200,600,14) . Это позволяет работать с любой картинкой нужного размера, а учить на меньших объектах, экономим память и время обработки, повышаем разнообразие в каждом пакекте (для медицинских фоток типа гистологий работает отлично, тут похуже).

# %%
 pre_trained_model = VGG16(input_shape=xTest.shape[1:], include_top=False, weights="imagenet")

# %% [markdown]
# Посмотрим на схему сети

# %%
pre_trained_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 200, 200, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 200, 200, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 200, 200, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 100, 100, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 100, 100, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 100, 100, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 50, 50, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 50, 50, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 50, 50, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 50, 50, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 25, 25, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 25, 25, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 12, 12, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Строим рабочую модель

# %%
def unet_pre_train(num_classes = 13, input_shape= (200, 200, 3)):  
    # грузим   VGG16
    pre_trained_model = VGG16(input_shape=input_shape, include_top=False, weights="imagenet")
    # замораживаем все слои
    for layer in pre_trained_model.layers[:18]:
      layer.trainable = False
    # фиксируем последний рабочий слой для своего потока  
    x = pre_trained_model.layers[13].output
    # фиксируем скипы для переноса из VGG16 (надо еще проверять)
    block_4_out = pre_trained_model.layers[10].output
    block_3_out = pre_trained_model.layers[6].output
    block_2_out = pre_trained_model.layers[3].output
    #  фиксируем вход сети
    img_input = pre_trained_model.inputs

    # задаем список скипов 
    blocks = [block_4_out, block_3_out, block_2_out]
    #print(block_4_out)
    #print(block_3_out)
    #print(block_2_out)
    # UP 1

    
    for i in [0,1,2]:
      x = concatenate([x, blocks[i]]) # добавили перенос из понижаюшего плеча VGG16
      x = Conv2D(256, (3, 3), padding='same')(x)
      x = BatchNormalization()(x)
      x = Activation('relu')(x)

      x = Conv2D(256, (3, 3), padding='same')(x)
      x = BatchNormalization()(x)
      x = Activation('relu')(x)
      # UP i
      x = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(x)
      x = BatchNormalization()(x)
      x = Activation('relu')(x)

    
    # последний слой сверток для классификации
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_classes, (3, 3), activation='softmax', padding='same')(x)
    # собираем модель 
    model = Model(img_input, x)
    model.compile(optimizer=Adam(),
                  loss='categorical_crossentropy',
                  metrics=[dice_coef])
    model.summary()
    # вернем модель
    return model

# %% [markdown]
# Создаем модель для кадров 200х200

# %%
modelU = unet_pre_train(num_classes = 14, input_shape= (200, 200, 3))

plot_model(modelU, to_file='modelU.png')
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 200, 200, 64) 1792        input_6[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 200, 200, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 100, 100, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 100, 100, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 100, 100, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 50, 50, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 50, 50, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 50, 50, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 50, 50, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 25, 25, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 25, 25, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 25, 25, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 25, 25, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 25, 25, 768)  0           block4_conv3[0][0]
#                                                                  block3_pool[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 25, 25, 256)  1769728     concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 25, 25, 256)  1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 25, 25, 256)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 25, 25, 256)  590080      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 25, 25, 256)  1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 25, 25, 256)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 50, 50, 256)  262400      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 50, 50, 256)  1024        conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 50, 50, 256)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 50, 50, 384)  0           activation_24[0][0]
#                                                                  block2_pool[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 50, 50, 256)  884992      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 50, 50, 256)  1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 50, 50, 256)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 50, 50, 256)  590080      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 50, 50, 256)  1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 50, 50, 256)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 100, 100, 256 262400      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 100, 100, 256 1024        conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 100, 100, 256 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 100, 100, 320 0           activation_27[0][0]
#                                                                  block1_pool[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 100, 100, 256 737536      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 100, 100, 256 1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 100, 100, 256 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 100, 100, 256 590080      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 100, 100, 256 1024        conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 100, 100, 256 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 200, 200, 256 262400      activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 200, 200, 256 1024        conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 200, 200, 256 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 200, 200, 64) 147520      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 200, 200, 64) 256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 200, 200, 64) 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 200, 200, 64) 36928       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 200, 200, 64) 256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 200, 200, 64) 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 200, 200, 14) 8078        activation_32[0][0]
# ==================================================================================================
# Total params: 13,787,214
# Trainable params: 6,147,086
# Non-trainable params: 7,640,128
# __________________________________________________________________________________________________

# %% [markdown]
# Обучаем по грубой схеме (шаг обучения в Adam по умолчанию) до 30 эпох

# %%
history = modelU.fit(xTrain, yTrain, epochs=30, batch_size=3, validation_data=(xTrain, yTrain))
# Out:
# Epoch 1/30
#  2/65 [..............................] - ETA: 10s - loss: 2.9293 - dice_coef: 0.0723WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0174s vs `on_train_batch_end` time: 0.1548s). Check your callbacks.
# 65/65 [==============================] - ETA: 0s - loss: 1.5809 - dice_coef: 0.3281WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0056s vs `on_test_batch_end` time: 0.0588s). Check your callbacks.
# 65/65 [==============================] - 15s 238ms/step - loss: 1.5809 - dice_coef: 0.3281 - val_loss: 2.5943 - val_dice_coef: 0.3618
# Epoch 2/30
# 65/65 [==============================] - 15s 233ms/step - loss: 1.2128 - dice_coef: 0.4514 - val_loss: 1.4808 - val_dice_coef: 0.4535
# Epoch 3/30
# 65/65 [==============================] - 15s 234ms/step - loss: 1.0502 - dice_coef: 0.5161 - val_loss: 1.6069 - val_dice_coef: 0.5299
# Epoch 4/30
# 65/65 [==============================] - 15s 235ms/step - loss: 0.9917 - dice_coef: 0.5368 - val_loss: 1.5710 - val_dice_coef: 0.4801
# Epoch 5/30
# 65/65 [==============================] - 15s 236ms/step - loss: 0.8709 - dice_coef: 0.5916 - val_loss: 2.7357 - val_dice_coef: 0.3670
# Epoch 6/30
# 65/65 [==============================] - 15s 236ms/step - loss: 0.8130 - dice_coef: 0.6168 - val_loss: 1.5687 - val_dice_coef: 0.5543
# Epoch 7/30
# 65/65 [==============================] - 15s 237ms/step - loss: 0.7108 - dice_coef: 0.6656 - val_loss: 0.8104 - val_dice_coef: 0.6383
# Epoch 8/30
# 65/65 [==============================] - 15s 238ms/step - loss: 0.6845 - dice_coef: 0.6792 - val_loss: 0.6824 - val_dice_coef: 0.6922
# Epoch 9/30
# 65/65 [==============================] - 15s 238ms/step - loss: 0.5845 - dice_coef: 0.7191 - val_loss: 0.5216 - val_dice_coef: 0.7526
# Epoch 10/30
# 65/65 [==============================] - 15s 238ms/step - loss: 0.5928 - dice_coef: 0.7185 - val_loss: 0.6601 - val_dice_coef: 0.6828
# Epoch 11/30
# 65/65 [==============================] - 15s 237ms/step - loss: 0.5621 - dice_coef: 0.7305 - val_loss: 0.6095 - val_dice_coef: 0.7382
# Epoch 12/30
# 65/65 [==============================] - 15s 238ms/step - loss: 0.4949 - dice_coef: 0.7618 - val_loss: 0.6270 - val_dice_coef: 0.7423
# Epoch 13/30
# 65/65 [==============================] - 16s 239ms/step - loss: 0.4848 - dice_coef: 0.7686 - val_loss: 0.5621 - val_dice_coef: 0.7707
# Epoch 14/30
# 65/65 [==============================] - 15s 237ms/step - loss: 0.4356 - dice_coef: 0.7855 - val_loss: 0.7044 - val_dice_coef: 0.7147
# Epoch 15/30
# 65/65 [==============================] - 15s 237ms/step - loss: 0.4486 - dice_coef: 0.7856 - val_loss: 0.5674 - val_dice_coef: 0.7732
# Epoch 16/30
# 65/65 [==============================] - 16s 239ms/step - loss: 0.3947 - dice_coef: 0.8082 - val_loss: 0.3737 - val_dice_coef: 0.8071
# Epoch 17/30
# 65/65 [==============================] - 15s 237ms/step - loss: 0.3843 - dice_coef: 0.8142 - val_loss: 0.3681 - val_dice_coef: 0.8103
# Epoch 18/30
# 65/65 [==============================] - 15s 237ms/step - loss: 0.4889 - dice_coef: 0.7769 - val_loss: 0.5899 - val_dice_coef: 0.7522
# Epoch 19/30
# 65/65 [==============================] - 15s 236ms/step - loss: 0.3607 - dice_coef: 0.8217 - val_loss: 0.3818 - val_dice_coef: 0.8127
# Epoch 20/30
# 65/65 [==============================] - 15s 237ms/step - loss: 0.3554 - dice_coef: 0.8265 - val_loss: 0.4034 - val_dice_coef: 0.8160
# Epoch 21/30
# 65/65 [==============================] - 15s 236ms/step - loss: 0.3256 - dice_coef: 0.8392 - val_loss: 0.3746 - val_dice_coef: 0.8126
# Epoch 22/30
# 65/65 [==============================] - 15s 237ms/step - loss: 0.3078 - dice_coef: 0.8475 - val_loss: 0.2640 - val_dice_coef: 0.8713
# Epoch 23/30
# 65/65 [==============================] - 15s 236ms/step - loss: 0.3603 - dice_coef: 0.8289 - val_loss: 0.5842 - val_dice_coef: 0.7672
# Epoch 24/30
# 65/65 [==============================] - 16s 239ms/step - loss: 0.2975 - dice_coef: 0.8517 - val_loss: 0.2609 - val_dice_coef: 0.8679
# Epoch 25/30
# 65/65 [==============================] - 15s 238ms/step - loss: 0.2719 - dice_coef: 0.8641 - val_loss: 0.3360 - val_dice_coef: 0.8294
# Epoch 26/30
# 65/65 [==============================] - 15s 238ms/step - loss: 0.2506 - dice_coef: 0.8730 - val_loss: 0.2764 - val_dice_coef: 0.8520
# Epoch 27/30
# 65/65 [==============================] - 15s 237ms/step - loss: 0.2585 - dice_coef: 0.8713 - val_loss: 0.3336 - val_dice_coef: 0.8602
# Epoch 28/30
# 65/65 [==============================] - 16s 239ms/step - loss: 0.2803 - dice_coef: 0.8638 - val_loss: 0.3364 - val_dice_coef: 0.8403
# Epoch 29/30
# 65/65 [==============================] - 15s 238ms/step - loss: 0.3062 - dice_coef: 0.8521 - val_loss: 0.4035 - val_dice_coef: 0.8238
# Epoch 30/30
# 65/65 [==============================] - 15s 238ms/step - loss: 0.2847 - dice_coef: 0.8593 - val_loss: 0.2473 - val_dice_coef: 0.8844

# %% [markdown]
# Визуализируем прогресс обучения

# %%
plt.plot(history.history['val_dice_coef'],label = 'test')
plt.plot(history.history['dice_coef'],label='train')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('dice_coef')
plt.show()

# %% [markdown]
# Сделаем более точное обучение (установим начальную скорость Adam 0.0001) и поставим ранний останов и контрольные точки модели

# %%
callback_ES = EarlyStopping(monitor='val_dice_coef',mode='max', patience=3)
callback_checkpoint = ModelCheckpoint( filepath='/content/cloned-repo', save_weights_only=True,
    monitor='val_dice_coef',  mode='max',  save_best_only=True)

# %%
modelU.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy',  metrics=[dice_coef])
history1 = modelU.fit(xTrain, yTrain, epochs=10, batch_size=3, validation_data=(xTrain, yTrain), callbacks=[callback_ES,callback_checkpoint])
# Out:
# Epoch 1/10
#  2/65 [..............................] - ETA: 5s - loss: 0.2920 - dice_coef: 0.8640WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0147s vs `on_train_batch_end` time: 0.1549s). Check your callbacks.
# 65/65 [==============================] - ETA: 0s - loss: 0.1976 - dice_coef: 0.8952WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0057s vs `on_test_batch_end` time: 0.0614s). Check your callbacks.
# 65/65 [==============================] - 16s 243ms/step - loss: 0.1976 - dice_coef: 0.8952 - val_loss: 0.1760 - val_dice_coef: 0.9064
# Epoch 2/10
# 65/65 [==============================] - 15s 235ms/step - loss: 0.1904 - dice_coef: 0.8999 - val_loss: 0.1855 - val_dice_coef: 0.8997
# Epoch 3/10
# 65/65 [==============================] - 16s 240ms/step - loss: 0.1856 - dice_coef: 0.9026 - val_loss: 0.1659 - val_dice_coef: 0.9102
# Epoch 4/10
# 65/65 [==============================] - 16s 240ms/step - loss: 0.1732 - dice_coef: 0.9080 - val_loss: 0.1622 - val_dice_coef: 0.9113
# Epoch 5/10
# 65/65 [==============================] - 16s 239ms/step - loss: 0.1741 - dice_coef: 0.9076 - val_loss: 0.1605 - val_dice_coef: 0.9113
# Epoch 6/10
# 65/65 [==============================] - 15s 235ms/step - loss: 0.1688 - dice_coef: 0.9110 - val_loss: 0.1626 - val_dice_coef: 0.9094
# Epoch 7/10
# 65/65 [==============================] - 16s 239ms/step - loss: 0.1658 - dice_coef: 0.9121 - val_loss: 0.1568 - val_dice_coef: 0.9133
# Epoch 8/10
# 65/65 [==============================] - 16s 240ms/step - loss: 0.1625 - dice_coef: 0.9139 - val_loss: 0.1545 - val_dice_coef: 0.9151
# Epoch 9/10
# 65/65 [==============================] - 16s 239ms/step - loss: 0.1591 - dice_coef: 0.9160 - val_loss: 0.1485 - val_dice_coef: 0.9183
# Epoch 10/10
# 65/65 [==============================] - 16s 239ms/step - loss: 0.1577 - dice_coef: 0.9166 - val_loss: 0.1458 - val_dice_coef: 0.9188

# %% [markdown]
# #Распознаём тестовую выборку

# %% [markdown]
# делаем предикт для примеров из тестов

# %%
predu = modelU.predict(xTest)
print(predu.shape)
# Out:
# (26, 200, 200, 14)

# %% [markdown]
# Отображаем эти примеры

# %%
n = 1 # номер примера
class_ = 4 # индекс класса для отображения
plt.figure(figsize=(16,16))
plt.subplot(3,3,1)
plt.imshow(xTest[n,:,:,:].astype(int))
plt.title('входной кадр')

plt.subplot(3,3,2)
img = yTest[n][:,:,class_]
plt.imshow(img.astype(float))
plt.title('целевая разметка класс: '+str(class_))
plt.subplot(3,3,3)
img = predu[n][:,:,class_]
plt.imshow(img.astype(float))
plt.title('предиктивная разметка класс: '+str(class_))
class_ = 0  # индекс класса для отображения
plt.figure(figsize=(16,16))
plt.subplot(3,3,4)
plt.imshow(xTest[n,:,:,:].astype(int))
plt.title('входной кадр')

plt.subplot(3,3,5)
img = yTest[n][:,:,class_]
plt.imshow(img.astype(float))
plt.title('целевая разметка класс: '+str(class_))
plt.subplot(3,3,6)
img = predu[n][:,:,class_]
plt.imshow(img.astype(float))
plt.title('предиктивная разметка класс: '+str(class_))

class_ = 10  # индекс класса для отображения
plt.figure(figsize=(16,16))
plt.subplot(3,3,7)
plt.imshow(xTest[n,:,:,:].astype(int))
plt.title('входной кадр')

plt.subplot(3,3,8)
img = yTest[n][:,:,class_]
plt.imshow(img.astype(float))
plt.title('целевая разметка класс: '+str(class_))
plt.subplot(3,3,9)
img = predu[n][:,:,class_]
plt.imshow(img.astype(float))
plt.title('предиктивная разметка класс: '+str(class_))

plt.show()

# %% [markdown]
# Сохраняем веса модели для построения большой модели.

# %%
modelU.save_weights('modelU_weight.h5')

# %% [markdown]
# Строю картинки для контроля работы большой модели (это будет 2 тестовые картинки размера 200х600 )

# %%
xTest_big=[]
yTest_big=[]
for i in range(2):
  img  = images[-1-i]
  seg = segments[-1-i]
  y_cat,_,_ = Color2index(image.img_to_array(seg))
  x = image.img_to_array(img)
  xTest_big.append(x)
  yTest_big.append(y_cat)
  

xTest_big = np.array(xTest_big)
yTest_big = np.array(yTest_big)

# %% [markdown]
# Перестраиваю модель на размер 200х600

# %%
pre_trained_model = VGG16(input_shape=xTest_big.shape[1:], include_top=False, weights="imagenet")

modelU_big = unet_pre_train(num_classes = 14, input_shape= (200, 600, 3))
# Out:
# Model: "functional_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           [(None, 200, 600, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 200, 600, 64) 1792        input_10[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 200, 600, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 100, 300, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 100, 300, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 100, 300, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 50, 150, 128) 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 50, 150, 256) 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 50, 150, 256) 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 50, 150, 256) 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 25, 75, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 25, 75, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 25, 75, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 25, 75, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 25, 75, 768)  0           block4_conv3[0][0]
#                                                                  block3_pool[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 25, 75, 256)  1769728     concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 25, 75, 256)  1024        conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 25, 75, 256)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 25, 75, 256)  590080      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 25, 75, 256)  1024        conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 25, 75, 256)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 50, 150, 256) 262400      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 50, 150, 256) 1024        conv2d_transpose_12[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 50, 150, 256) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 50, 150, 384) 0           activation_46[0][0]
#                                                                  block2_pool[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 50, 150, 256) 884992      concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 50, 150, 256) 1024        conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 50, 150, 256) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 50, 150, 256) 590080      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 50, 150, 256) 1024        conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 50, 150, 256) 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 100, 300, 256 262400      activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 100, 300, 256 1024        conv2d_transpose_13[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 100, 300, 256 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 100, 300, 320 0           activation_49[0][0]
#                                                                  block1_pool[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 100, 300, 256 737536      concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 100, 300, 256 1024        conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 100, 300, 256 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 100, 300, 256 590080      activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 100, 300, 256 1024        conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 100, 300, 256 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 200, 600, 256 262400      activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 200, 600, 256 1024        conv2d_transpose_14[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 200, 600, 256 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 200, 600, 64) 147520      activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 200, 600, 64) 256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 200, 600, 64) 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 200, 600, 64) 36928       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 200, 600, 64) 256         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 200, 600, 64) 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 200, 600, 14) 8078        activation_54[0][0]
# ==================================================================================================
# Total params: 13,787,214
# Trainable params: 6,147,086
# Non-trainable params: 7,640,128
# __________________________________________________________________________________________________

# %% [markdown]
# Грузим веса из маленькой модели в большую (полносвязных слоев нет и размеры ядер не изменяются - веса одинаковые при любых размерах входов)

# %%
modelU_big.load_weights('modelU_weight.h5')

# %% [markdown]
# # Проверка для модели полного размера
#
# делаем предсказание и визуализируем его

# %%
predu_big = modelU_big.predict(xTest_big)
print(predu_big.shape)
# Out:
# (2, 200, 600, 14)

# %%
n = 0 # номер примера для отображения (0 или 1))
class_ = 10 # индекс класса для отображения (от 0 до 13)


plt.imshow(xTest_big[n,:,:,:].astype(int))
plt.title('входной кадр')
plt.show()

img = yTest_big[n][:,:,class_]
plt.imshow(img.astype(float))
plt.title('целевая разметка класс: '+str(class_))
plt.show()

img = predu_big[n][:,:,class_]
plt.imshow(img.astype(float))
plt.title('предиктивная разметка класс: '+str(class_)+' : for class DICE coef ='+str((dice_coef(K.constant(yTest_big[n,:,:,class_]),K.constant(  predu_big[n,:,:,class_]))).numpy()))
plt.show()

print('All samples DICE coeff = ',dice_coef(K.constant(yTest_big),K.constant(predu_big)).numpy())
# Out:
# All samples DICE coeff =  0.70147216

# %% [markdown]
# Результат Распознавания новых картинок: DICE coeff =  0.70147216 по всем классам
